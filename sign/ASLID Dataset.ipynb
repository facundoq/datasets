# %% [markdown]
# # ASLID Dataset
#
# Website: http://vlm1.uta.edu/~srujana/ASLID/ASL_Image_Dataset.html
#
# Original info:
#
# We present the American Sign Language Image Dataset (ASLID) with images extracted from Gallaudet Dictionary videos[1] and American Sign Language Lexicon Video Dataset(ASLLVD)[2] with annotations for upper body joint locations. The annotation file contains image video and frame name and 7 upper body joint co-ordinates, namely left hand, left elbow, left shoulder, head, right hand, right shoulder, right wrist. We also provide a tool to visualize the annotations. For the purpose of Upper body pose estimation experiments we have segregated the training and test set.
#
#
#
#
# * [1] C. Valli, editor. The Gallaudet Dictionary of American Sign Language. Gallaudet U. Press, Washington, DC, 2006.
# * [2] http://www.bu.edu/av/asllrp/dai-asllvd.html

# %%
# %load_ext autoreload 
# %autoreload 2

import matplotlib.pyplot as plt
import aslid
import target

target=target.LocalizationTargetRegression(20,['lwri','rwri','nose'])



# basepath='/home/facundo/datasets/pose/aslid/'
basepath='/data/datases/'

iterator=aslid.ASLIDIterator(basepath,'train',target,batch_size=4)
print(iterator)

xb,yb=iterator.next()
print(yb)
print(xb.shape)
i=3
plt.imshow(xb[i,:,:,:])
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-7475ed16200e> in <module>()
#      11
#      12 basepath='/home/facundo/datasets/pose/aslid/'
# ---> 13 iterator=aslid.ASLIDIterator(basepath,'train',target,batch_size=4)
#      14 print(iterator)
#      15
#
# /data/dev/datasets/sign/aslid.py in __init__(self, basepath, dataset, localization_target, batch_size, shuffle, seed, resize)
#      50         self.annotations_filepath=os.path.join(basepath,"%s.csv" % dataset)
#      51
# ---> 52         self.samples=self.read_annotations(self.images_path,self.annotations_filepath)
#      53         super().__init__(len(self.samples), batch_size, shuffle, seed)
#      54
#
# /data/dev/datasets/sign/aslid.py in read_annotations(self, images_path, annotations_filepath)
#      63         filename="train.csv"
#      64
# ---> 65         positions=np.loadtxt(annotations_filepath,delimiter=',',usecols=list(range(1,15)))
#      66         n,m=positions.shape
#      67         positions=positions.reshape(n,m//2,2)
#
# /data/dev/datasets/.env/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# --> 917             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     918             fencoding = getattr(fh, 'encoding', 'latin1')
#     919             fh = iter(fh)
#
# /data/dev/datasets/.env/lib/python3.5/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     258
#     259     ds = DataSource(destpath)
# --> 260     return ds.open(path, mode, encoding=encoding, newline=newline)
#     261
#     262
#
# /data/dev/datasets/.env/lib/python3.5/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     614                                       encoding=encoding, newline=newline)
#     615         else:
# --> 616             raise IOError("%s not found." % path)
#     617
#     618
#
# OSError: /home/facundo/datasets/pose/aslid/train.csv not found.

# %%
basepath='/home/facundo/datasets/pose/aslid/'
samples,images=aslid.read_all(basepath,'test')
print(len(samples))
import random
i=random.randint(0, len(samples))
sample=samples[i]
image=images[i]
plt.imshow(image)
for body_part in aslid.body_parts:
    position=sample.positions[body_part]
    plt.scatter(position[0],position[1])
plt.show()
# Out:
# 473
